# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import sklearn as sk 

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Data exploration

# %%
# apple mobility data
apple_mobility = pd.read_csv("https://covid19-static.cdn-apple.com/covid19-mobility-data/2204HotfixDev11/v3/en-us/applemobilitytrends-2021-12-17.csv")
# Out:
# /Users/jessbunnag/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# get data 
factors = pd.read_csv('datasets/covid-state-data-agg/COVID19_state.csv')
covid_cases = pd.read_csv('datasets/covid-cases-data/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')
state_trips = pd.read_csv('datasets/bts-travel-data/State_trips.csv')
blue_red = pd.read_csv('datasets/BlueRedStates.csv').drop(columns=['BlueRed'])

# %%
# filter date and format date col 
ny_cols = ['NY', 'NYC']

def filterByYear(df, date_col, year):
    df[date_col] = pd.to_datetime(df[date_col], infer_datetime_format=True)
    return df[df[date_col].dt.strftime('%Y') == year]

covid_cases_cols = ['submission_date', 'state', 'new_case', 'tot_cases']
covid_cases = covid_cases[covid_cases_cols]
covid_cases = filterByYear(covid_cases, 'submission_date', '2020')

covid_cases[(covid_cases['submission_date'] == '2020-12-31')].sort_values('state')
# Out:
#       submission_date state  new_case  tot_cases
# 964        2020-12-31    AK     372.0      45771
# 26793      2020-12-31    AL    4784.0     362094
# 2191       2020-12-31    AR    2708.0     225138
# 38784      2020-12-31    AS       0.0          3
# 17831      2020-12-31    AZ    7721.0     520559
# 14904      2020-12-31    CA   13410.0    2231552
# 33652      2020-12-31    CO    2858.0     347198
# 15224      2020-12-31    CT    2045.0     185708
# 29404      2020-12-31    DC     225.0      28983
# 10103      2020-12-31    DE     626.0      58847
# 36681      2020-12-31    FL   20939.0    1318256
# 17033      2020-12-31   FSM       0.0          0
# 2757       2020-12-31    GA   11709.0     666452
# 9715       2020-12-31    GU       0.0       7308
# 37709      2020-12-31    HI     175.0      21026
# 40300      2020-12-31    IA    1710.0     280669
# 8901       2020-12-31    ID    1213.0     141077
# 27367      2020-12-31    IL    8009.0     963389
# 15097      2020-12-31    IN    6480.0     511698
# 38865      2020-12-31    KS       0.0     222433
# 30229      2020-12-31    KY    4184.0     275530
# 29078      2020-12-31    LA    4046.0     315275
# 33359      2020-12-31    MA    7260.0     375178
# 22072      2020-12-31    MD    3557.0     280219
# 22869      2020-12-31    ME      13.0      24201
# 25491      2020-12-31    MI    2567.0     589728
# 29831      2020-12-31    MN    2195.0     415302
# 24209      2020-12-31    MO    3800.0     449569
# 34227      2020-12-31    MP       0.0        122
# 23141      2020-12-31    MS    2566.0     221928
# 10446      2020-12-31    MT     255.0      81555
# 27501      2020-12-31    NC   10406.0     550145
# 10419      2020-12-31    ND     275.0      92770
# 9114       2020-12-31    NE    1473.0     167233
# 28685      2020-12-31    NH     786.0      44028
# 32038      2020-12-31    NJ    5525.0     527784
# 40162      2020-12-31    NM    1678.0     142864
# 13160      2020-12-31    NV    2137.0     224731
# 6747       2020-12-31    NY   10809.0     548154
# 4201       2020-12-31   NYC    6218.0     442472
# 39282      2020-12-31    OH    9632.0     700380
# 4442       2020-12-31    OK    4151.0     325524
# 29386      2020-12-31    OR    1649.0     113909
# 41518      2020-12-31    PA    8374.0     648569
# 36727      2020-12-31    PR     805.0      79858
# 38791      2020-12-31    PW       0.0          0
# 19839      2020-12-31    RI    1376.0      89476
# 40293      2020-12-31   RMI       0.0          4
# 18539      2020-12-31    SC    4936.0     317350
# 7441       2020-12-31    SD     444.0      99164
# 8063       2020-12-31    TN    6690.0     576503
# 38084      2020-12-31    TX   18725.0    1756172
# 3750       2020-12-31    UT    4672.0     276612
# 17060      2020-12-31    VA    5183.0     354767
# 9082       2020-12-31    VI       5.0       2036
# 22616      2020-12-31    VT     138.0       6966
# 11494      2020-12-31    WA    3958.0     246413
# 27157      2020-12-31    WI    4212.0     520438
# 34295      2020-12-31    WV    1109.0      85334
# 31434      2020-12-31    WY     276.0      44409

# %%
# WAY1: merge NY and NYC data
cases_indexed = covid_cases.groupby(['submission_date','state']).sum()

indexes = cases_indexed.index
date_index = np.unique(np.array([ind[0] for ind in indexes]))

for date_ind in date_index: 
    cases_indexed.loc[date_ind, 'NY'] = sum(cases_indexed.loc[date_ind, 'NY'], cases_indexed.loc[date_ind, 'NYC'])

cases_indexed.reset_index(inplace=True, level=['submission_date', 'state'])

new_cases = cases_indexed
new_cases[(new_cases['submission_date'] == '2020-12-31')].sort_values('state').head(10)
# Out:
#       submission_date state  new_case  tot_cases
# 20640      2020-12-31    AK     372.0    45771.0
# 20641      2020-12-31    AL    4784.0   362094.0
# 20642      2020-12-31    AR    2708.0   225138.0
# 20643      2020-12-31    AS       0.0        3.0
# 20644      2020-12-31    AZ    7721.0   520559.0
# 20645      2020-12-31    CA   13410.0  2231552.0
# 20646      2020-12-31    CO    2858.0   347198.0
# 20647      2020-12-31    CT    2045.0   185708.0
# 20648      2020-12-31    DC     225.0    28983.0
# 20649      2020-12-31    DE     626.0    58847.0

# %%
# state trips data 
state_trips_col = ['Date', 
                   'State Postal Code', 
                   'Number of Trips', 
                   'Number of Trips 5-10', 
                   'Number of Trips 25-50', 
                   'Number of Trips 100-250', 
                   'Number of Trips 250-500']
state_trips = state_trips[state_trips_col]
state_trips = filterByYear(state_trips, 'Date', '2020')

# check state num
state_trips.groupby(['Date']).size().reset_index(name='counts')

state_trips.head()
# Out:
#             Date State Postal Code Number of Trips Number of Trips 5-10  \
# 18615 2020-01-01                MS       7,629,798            1,221,867
# 18616 2020-01-01                CA     112,606,885           15,443,353
# 18617 2020-01-01                CO      18,346,137            2,712,409
# 18618 2020-01-01                CT       9,636,627            1,491,090
# 18619 2020-01-01                DE       2,665,377              432,958
#
#       Number of Trips 25-50 Number of Trips 100-250 Number of Trips 250-500
# 18615               396,415                  93,571                  22,897
# 18616             5,553,845                 839,553                 174,752
# 18617               807,692                 141,931                  39,387
# 18618               464,270                  49,982                  10,008
# 18619               140,146                  15,988                   1,121

# %%
new_cases.rename(columns={'submission_date' : 'date'}, inplace=True)
state_trips.rename(columns={'Date' : 'date', 'State Postal Code' : 'state'}, inplace=True)

# get population by state
factors = factors[['State', 'Population']]
pop_by_state = blue_red.merge(factors, left_on='stateName', right_on='State')\
    .drop(columns=['stateName', 'State'])\
    .rename(columns={'stateCode' : 'state'})

# merge all dfs
new_case_trips = new_cases.merge(state_trips, on=['date', 'state'], how='inner')
final_data = new_case_trips.merge(pop_by_state, on='state', how='inner')
final_data.replace(',','', regex=True, inplace=True)


# normalize number of trips 
num_trips_cols = ['Number of Trips', 'Number of Trips 5-10', 'Number of Trips 25-50', 'Number of Trips 100-250', 'Number of Trips 250-500']
for col in num_trips_cols:
    final_data[col] = final_data[col].astype(float) / final_data['Population']

# normalize num of new cases
final_data['new_case'] = final_data['new_case']  / final_data['Population']
final_data['tot_cases'] = final_data['tot_cases']  / final_data['Population']

# drop 0 new cases 
# index_to_drop = final_data[final_data['new_case'] == 0].index
# final_data.drop(index_to_drop, inplace=True)

final_data[final_data['new_case'] == 0].count
# Out:
# <bound method DataFrame.count of             date state  new_case  tot_cases  Number of Trips  \
# 0     2020-01-22    AK       0.0   0.000000         4.018937
# 1     2020-01-23    AK       0.0   0.000000         3.814015
# 2     2020-01-24    AK       0.0   0.000000         3.904329
# 3     2020-01-25    AK       0.0   0.000000         3.388376
# 4     2020-01-26    AK       0.0   0.000000         3.126530
# ...          ...   ...       ...        ...              ...
# 16965 2020-03-22    WY       0.0   0.000042         2.748133
# 17134 2020-09-07    WY       0.0   0.007111         2.662851
# 17214 2020-11-26    WY       0.0   0.054250         2.452647
# 17242 2020-12-24    WY       0.0   0.075242         2.710873
# 17243 2020-12-25    WY       0.0   0.075242         1.626549
#
#        Number of Trips 5-10  Number of Trips 25-50  Number of Trips 100-250  \
# 0                  0.561167               0.152170                 0.011189
# 1                  0.540654               0.167809                 0.015574
# 2                  0.563700               0.162727                 0.011970
# 3                  0.506086               0.143344                 0.009590
# 4                  0.443621               0.122897                 0.011651
# ...                     ...                    ...                      ...
# 16965              0.243425               0.187173                 0.048463
# 17134              0.277637               0.197716                 0.085159
# 17214              0.270679               0.174133                 0.046765
# 17242              0.269916               0.237564                 0.068251
# 17243              0.192577               0.144050                 0.042557
#
#        Number of Trips 250-500  Population
# 0                     0.001877      734002
# 1                     0.002390      734002
# 2                     0.015670      734002
# 3                     0.001495      734002
# 4                     0.005644      734002
# ...                        ...         ...
# 16965                 0.010744      567025
# 17134                 0.012724      567025
# 17214                 0.009335      567025
# 17242                 0.010495      567025
# 17243                 0.008698      567025
#
# [2763 rows x 10 columns]>

# %%
corr_matrix = final_data.corr()

corr_matrix
# Out:
#                          new_case  tot_cases  Number of Trips  \
# new_case                 1.000000   0.204772         0.041899
# tot_cases                0.204772   1.000000        -0.269391
# Number of Trips          0.041899  -0.269391         1.000000
# Number of Trips 5-10     0.044466  -0.192799         0.867849
# Number of Trips 25-50   -0.084649  -0.017957         0.602418
# Number of Trips 100-250 -0.071527   0.089143         0.109070
# Number of Trips 250-500 -0.082167   0.095549         0.047523
# Population               0.193387   0.014180        -0.100724
#
#                          Number of Trips 5-10  Number of Trips 25-50  \
# new_case                             0.044466              -0.084649
# tot_cases                           -0.192799              -0.017957
# Number of Trips                      0.867849               0.602418
# Number of Trips 5-10                 1.000000               0.489367
# Number of Trips 25-50                0.489367               1.000000
# Number of Trips 100-250             -0.067100               0.354798
# Number of Trips 250-500             -0.020159               0.159573
# Population                          -0.013639              -0.135838
#
#                          Number of Trips 100-250  Number of Trips 250-500  \
# new_case                               -0.071527                -0.082167
# tot_cases                               0.089143                 0.095549
# Number of Trips                         0.109070                 0.047523
# Number of Trips 5-10                   -0.067100                -0.020159
# Number of Trips 25-50                   0.354798                 0.159573
# Number of Trips 100-250                 1.000000                 0.781042
# Number of Trips 250-500                 0.781042                 1.000000
# Population                             -0.199774                -0.112498
#
#                          Population
# new_case                   0.193387
# tot_cases                  0.014180
# Number of Trips           -0.100724
# Number of Trips 5-10      -0.013639
# Number of Trips 25-50     -0.135838
# Number of Trips 100-250   -0.199774
# Number of Trips 250-500   -0.112498
# Population                 1.000000

# %%
num_trips = np.array(final_data['Number of Trips'].astype(float)).reshape(-1, 1)
num_new_cases = final_data['new_case']

X_train, X_test, y_train, y_test = train_test_split(num_trips, num_new_cases, test_size=0.20)

model = LinearRegression()
model.fit(X_train, y_train)

# make a prediction
y_train_hat = model.predict(X_train)
y_test_hat = model.predict(X_test)

# find error
training_error = mean_squared_error(y_train, y_train_hat)
testing_error = mean_squared_error(y_test, y_test_hat)

print(training_error)
print(testing_error)
# Out:
# 890671651.2271935
# 1032965858.3417673

# %% [markdown]
# Apply mobility data

# %%
apple_mobility.head()
# Out:
#          geo_type     region transportation_type alternative_name sub-region  \
# 0  country/region    Albania             driving              NaN        NaN
# 1  country/region    Albania             walking              NaN        NaN
# 2  country/region  Argentina             driving              NaN        NaN
# 3  country/region  Argentina             walking              NaN        NaN
# 4  country/region  Australia             driving               AU        NaN
#
#   country  2020-01-13  2020-01-14  2020-01-15  2020-01-16  ...  2021-12-08  \
# 0     NaN       100.0       95.30      101.43       97.20  ...      171.58
# 1     NaN       100.0      100.68       98.93       98.46  ...      244.65
# 2     NaN       100.0       97.07      102.45      111.21  ...       98.74
# 3     NaN       100.0       95.11      101.37      112.67  ...       84.15
# 4     NaN       100.0      102.98      104.21      108.63  ...      138.88
#
#    2021-12-09  2021-12-10  2021-12-11  2021-12-12  2021-12-13  2021-12-14  \
# 0      159.52      173.82      170.79      154.11      156.63      145.56
# 1      203.88      221.58      189.47      159.06      233.01      216.16
# 2      115.38      142.73      153.72       89.45      100.86      105.01
# 3      114.29      135.13      125.15       67.77      104.04      107.03
# 4      146.07      142.32      119.83      130.54      133.84      141.14
#
#    2021-12-15  2021-12-16  2021-12-17
# 0      151.96      160.56      178.86
# 1      214.03      214.63      239.49
# 2      115.63      125.54      155.04
# 3      118.26      124.31      138.56
# 4      143.24      151.64      138.80
#
# [5 rows x 711 columns]

# %%
apple_mobility[apple_mobility['country'] == "United States"]
# Out:
#      geo_type        region transportation_type alternative_name  \
# 158      city         Akron             driving              NaN
# 159      city         Akron             transit              NaN
# 160      city         Akron             walking              NaN
# 161      city        Albany             driving              NaN
# 162      city        Albany             transit              NaN
# ...       ...           ...                 ...              ...
# 4686   county   York County             walking              NaN
# 4687   county  Young County             driving              NaN
# 4688   county   Yuba County             driving              NaN
# 4689   county   Yuma County             driving              NaN
# 4690   county   Yuma County             walking              NaN
#
#         sub-region        country  2020-01-13  2020-01-14  2020-01-15  \
# 158           Ohio  United States       100.0      103.06      107.50
# 159           Ohio  United States       100.0      106.69      103.75
# 160           Ohio  United States       100.0       97.23       79.05
# 161       New York  United States       100.0      102.35      107.35
# 162       New York  United States       100.0      100.14      105.95
# ...            ...            ...         ...         ...         ...
# 4686  Pennsylvania  United States       100.0      110.22      121.82
# 4687         Texas  United States       100.0       98.85       97.76
# 4688    California  United States       100.0      102.98      103.10
# 4689       Arizona  United States       100.0      101.82      106.67
# 4690       Arizona  United States       100.0       95.88       98.97
#
#       2020-01-16  ...  2021-12-08  2021-12-09  2021-12-10  2021-12-11  \
# 158       106.14  ...      146.38      154.32      179.24      167.41
# 159       100.22  ...       65.00       68.68       72.65       61.03
# 160        74.77  ...      118.31      122.80      145.72      136.49
# 161       105.54  ...      138.98      146.57      166.43      154.37
# 162       107.76  ...      146.68      149.19      159.92      155.78
# ...          ...  ...         ...         ...         ...         ...
# 4686      109.72  ...      191.71      197.18      223.87      209.56
# 4687       92.21  ...      176.96      179.00      244.99      176.08
# 4688      114.08  ...      169.29      168.30      191.33      177.60
# 4689      108.93  ...      157.59      160.94      188.79      178.68
# 4690       92.88  ...      182.58      206.09      225.41      230.30
#
#       2021-12-12  2021-12-13  2021-12-14  2021-12-15  2021-12-16  2021-12-17
# 158       121.65      142.76      152.04      155.13      162.09      180.14
# 159        49.85       71.32       70.22       65.44       62.72       66.47
# 160        99.43      112.08      113.91      121.07      128.97      140.42
# 161       118.06      138.81      147.73      147.86      154.41      178.21
# 162       113.66      135.25      137.81      131.96      133.02      137.81
# ...          ...         ...         ...         ...         ...         ...
# 4686      167.35      184.86      196.13      209.28      211.66      250.22
# 4687      139.50      154.95      163.01      166.46      166.73      221.07
# 4688      121.76      142.89      148.62      159.91      169.67      198.52
# 4689      129.67      153.52      155.95      163.20      169.46      202.46
# 4690      141.80      177.34      178.45      165.84      179.57      233.05
#
# [3102 rows x 711 columns]

# %%
dates_2020 = [col for col in apple_mobility.columns if col.startswith('2020')]

mobility_cols = ['transportation_type', 'sub-region'] + dates_2020
mobility_us = apple_mobility[apple_mobility['country'] == "United States"][mobility_cols]

mobility_us.rename(columns={'sub-region':'state'}, inplace=True)
mobility_us

mobility_us = mobility_us.melt(id_vars=["transportation_type", "state"], var_name="date", value_name="mobility")

# make new column based on transportation type
for value in ['driving', 'walking', 'transit']:
    mobility_us[f'mobility_{value}'] = np.where(mobility_us['transportation_type'] == value, mobility_us['mobility'].astype(float), float("NaN"))
    
mobility_us.drop(columns=['transportation_type', 'mobility'], inplace=True)

mobility_us_indexed = mobility_us.groupby(['state', 'date']).first()
mobility_us_indexed.reset_index(inplace=True, level=['date', 'state'])
mobility_us_indexed['date'] = pd.to_datetime(mobility_us_indexed['date'], infer_datetime_format=True)

mobility_us_indexed
# Out:
#          state       date  mobility_driving  mobility_walking  \
# 0      Alabama 2020-01-13            100.00            100.00
# 1      Alabama 2020-01-14            100.39             94.69
# 2      Alabama 2020-01-15            101.95             98.19
# 3      Alabama 2020-01-16            105.97            102.98
# 4      Alabama 2020-01-17            124.99            122.60
# ...        ...        ...               ...               ...
# 18757  Wyoming 2020-12-27            180.01               NaN
# 18758  Wyoming 2020-12-28            173.78               NaN
# 18759  Wyoming 2020-12-29            176.76               NaN
# 18760  Wyoming 2020-12-30            179.88               NaN
# 18761  Wyoming 2020-12-31            189.26               NaN
#
#        mobility_transit
# 0                100.00
# 1                105.69
# 2                102.70
# 3                104.55
# 4                114.79
# ...                 ...
# 18757               NaN
# 18758               NaN
# 18759               NaN
# 18760               NaN
# 18761               NaN
#
# [18762 rows x 5 columns]

# %%
# mobility_by_state
mobility_by_state = blue_red.merge(mobility_us_indexed, left_on='stateName', right_on='state')\
    .drop(columns=['stateName', 'state'])\
    .rename(columns={'stateCode': 'state'})

# merge all dfs
new_case_vs_mobility = new_cases.merge(mobility_by_state, on=['date', 'state'], how='inner')
final_data2 = new_case_vs_mobility.merge(pop_by_state, on='state', how='inner')
final_data2.replace(',','', regex=True, inplace=True)
final_data2
# Out:
#             date state  new_case  tot_cases  mobility_driving  \
# 0     2020-01-22    AK       0.0        0.0            104.94
# 1     2020-01-23    AK       0.0        0.0            106.87
# 2     2020-01-24    AK       0.0        0.0            123.88
# 3     2020-01-25    AK       0.0        0.0            114.35
# 4     2020-01-26    AK       0.0        0.0             81.75
# ...          ...   ...       ...        ...               ...
# 17245 2020-12-27    WY      54.0    43200.0            180.01
# 17246 2020-12-28    WY     504.0    43704.0            173.78
# 17247 2020-12-29    WY     219.0    43923.0            176.76
# 17248 2020-12-30    WY     210.0    44133.0            179.88
# 17249 2020-12-31    WY     276.0    44409.0            189.26
#
#        mobility_walking  mobility_transit  Population
# 0                 99.90               NaN      734002
# 1                 94.30               NaN      734002
# 2                120.33               NaN      734002
# 3                112.05               NaN      734002
# 4                 80.32               NaN      734002
# ...                 ...               ...         ...
# 17245               NaN               NaN      567025
# 17246               NaN               NaN      567025
# 17247               NaN               NaN      567025
# 17248               NaN               NaN      567025
# 17249               NaN               NaN      567025
#
# [17250 rows x 8 columns]

# %%
final_data2.groupby("state")[['mobility_driving', 'mobility_walking', 'mobility_transit']].mean()
# Out:
#        mobility_driving  mobility_walking  mobility_transit
# state
# AK           132.928746        135.345884               NaN
# AL           110.379679        120.780667         92.547843
# AR            98.639708        146.719507               NaN
# AZ            95.980175         96.992841         59.904928
# CA           117.728630        144.738116         57.675971
# CO           130.612828        146.659855         78.849681
# CT           109.746531        127.275594         63.182580
# DE           123.376385        147.391304         60.804725
# FL           109.335977        123.682986         70.063304
# GA           114.212799        122.412406         59.707739
# HI            70.322945         48.317420         30.887536
# IA           140.644169        185.133449               NaN
# ID           129.070933        150.675449               NaN
# IL           106.837551        106.213072         48.156957
# IN           130.818688        170.620145         67.197275
# KS           126.297172        158.360551               NaN
# KY           116.639213        134.150029         61.796754
# LA            62.136589         23.473768         43.766116
# MA            94.085306         86.894493         50.102696
# MD           112.548163        132.330522         58.666116
# ME           137.609796        157.342087               NaN
# MI            93.546064         79.624754         30.396029
# MN           101.491370        144.360261         50.364464
# MO           114.005423        141.682435         72.922812
# MS           136.663178        165.860116               NaN
# MT           140.174373        186.293768               NaN
# NC           116.701662        134.446174         69.547594
# ND           141.316152        148.107710               NaN
# NE           127.405190         76.128145         75.922536
# NH           181.348484        147.188348               NaN
# NJ           144.502070        204.815217         56.766841
# NM           105.803819        128.214058         53.722899
# NV           112.403673        107.902696         62.391101
# NY           107.627055        121.648899         80.276058
# OH           120.957172         94.558406         53.698174
# OK           118.161662        105.269420         92.862507
# OR           123.265598        107.826174         43.697971
# PA           117.689504        144.112783         70.434377
# RI           117.048426        129.121797         61.339043
# SC           116.397318         64.266203               NaN
# SD           115.399329               NaN               NaN
# TN           123.842799        148.733420         76.491623
# TX            98.769796        116.989333         62.293217
# UT           120.750700        141.407536         55.362899
# VA           122.120816        138.586609         65.313855
# VT           122.084402         96.799594               NaN
# WA           117.493353        100.313130         39.045507
# WI           115.755306        151.347797         68.574928
# WV           138.673557         99.740116               NaN
# WY           229.038047               NaN               NaN

# %%
# for value in ['mobility_driving', 'mobility_walking', 'mobility_transit']:
cols = ['mobility_driving', 'mobility_walking', 'mobility_transit']
mean_cols = [f'avg_{col}' for col in cols]
print(mean_cols)
col_rename_dict = {i:j for i,j in zip(cols,mean_cols)}

# print(col)
mobility_means = final_data2.groupby("state")[cols].mean()
mobility_means = mobility_means.fillna(value=mobility_means.mean())
mobility_means.rename(columns=col_rename_dict, inplace=True)
# print(mobility_means)

finalWithMeans = final_data2.merge(mobility_means, on="state")
# print(stateMeansMap)

final_data_filled = finalWithMeans.copy()
# print(final_data_filled)

for mob_col in cols:
    final_data_filled[mob_col] = final_data_filled[mob_col]\
                    .fillna(final_data_filled[f'avg_{mob_col}'])

final_data_filled.drop(columns=mean_cols, inplace=True)
# print(f"na before {final_data2[value].isna().sum()} ")
# print(f"na after {final_data_filled[value].isna().sum()}" )

# normalize num of new cases
final_data_filled['new_case'] = final_data_filled['new_case'] / final_data_filled['Population']

final_data_filled.corr()
# Out:
# ['avg_mobility_driving', 'avg_mobility_walking', 'avg_mobility_transit']
#                   new_case  tot_cases  mobility_driving  mobility_walking  \
# new_case          1.000000   0.322748         -0.023781          0.017895
# tot_cases         0.322748   1.000000         -0.033671          0.085361
# mobility_driving -0.023781  -0.033671          1.000000          0.690459
# mobility_walking  0.017895   0.085361          0.690459          1.000000
# mobility_transit  0.043686  -0.103711          0.290803          0.339240
# Population        0.193387   0.567247         -0.127854         -0.008260
#
#                   mobility_transit  Population
# new_case                  0.043686    0.193387
# tot_cases                -0.103711    0.567247
# mobility_driving          0.290803   -0.127854
# mobility_walking          0.339240   -0.008260
# mobility_transit          1.000000    0.020543
# Population                0.020543    1.000000

# %%
final_data_filled['mobility_walking'].isna().sum()
# Out:
# 0

# %%
# final_data2.groupby("state").transform(lambda x: x.fillna(x.mean()))
# Out:
# <ipython-input-467-ff65ab1a6ddb>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   final_data2.groupby("state").transform(lambda x: x.fillna(x.mean()))
#             date  new_case  mobility_driving  mobility_walking  \
# 0     2020-01-22       0.0            104.94             99.90
# 1     2020-01-23       0.0            106.87             94.30
# 2     2020-01-24       0.0            123.88            120.33
# 3     2020-01-25       0.0            114.35            112.05
# 4     2020-01-26       0.0             81.75             80.32
# ...          ...       ...               ...               ...
# 17245 2020-12-27      54.0            180.01               NaN
# 17246 2020-12-28     504.0            173.78               NaN
# 17247 2020-12-29     219.0            176.76               NaN
# 17248 2020-12-30     210.0            179.88               NaN
# 17249 2020-12-31     276.0            189.26               NaN
#
#        mobility_transit  Population
# 0                   NaN      734002
# 1                   NaN      734002
# 2                   NaN      734002
# 3                   NaN      734002
# 4                   NaN      734002
# ...                 ...         ...
# 17245               NaN      567025
# 17246               NaN      567025
# 17247               NaN      567025
# 17248               NaN      567025
# 17249               NaN      567025
#
# [17250 rows x 6 columns]

# %%
final_data2[final_data2['']]

# %%
final_data2.corr()
# Out:
#                   new_case  tot_cases  mobility_driving  mobility_walking  \
# new_case          1.000000   0.326529         -0.028309          0.004737
# tot_cases         0.326529   1.000000         -0.033588          0.085759
# mobility_driving -0.028309  -0.033588          1.000000          0.787151
# mobility_walking  0.004737   0.085759          0.787151          1.000000
# mobility_transit  0.054748  -0.108042          0.455786          0.421140
# Population        0.238646   0.567247         -0.127588         -0.008371
#
#                   mobility_transit  Population
# new_case                  0.054748    0.238646
# tot_cases                -0.108042    0.567247
# mobility_driving          0.455786   -0.127588
# mobility_walking          0.421140   -0.008371
# mobility_transit          1.000000    0.023017
# Population                0.023017    1.000000

# %%
from sklearn.tree import DecisionTreeRegressor

num_trips = np.array(final_data_filled['mobility_transit'].astype(float)).reshape(-1, 1)
num_new_cases = final_data['new_case']

X_train, X_test, y_train, y_test = train_test_split(num_trips, num_new_cases, test_size=0.20)

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X_train, y_train)
regr_2.fit(X_train, y_train)

# Predict
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X_train, y_train, s=20, edgecolor="black", c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue", label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
plt.scatter(X_test, y_test, s=20, edgecolor="black", c="darkorange", label="data")

# %% [markdown]
# 5      0.27             03/23/20
# 6      0.32             03/17/20
# 7      0.22             03/16/20
# 8      0.33             03/16/20
# 9      0.35             03/16/20
# 10     0.26             03/18/20
# 11     0.32             03/23/20
# 12     0.30                  NaN
# 13     0.28             03/23/20
# 14     0.28             03/17/20
# 15     0.29             03/19/20
# 16     0.29             03/18/20
# 17     0.30             03/16/20
# 18     0.28             03/16/20
# 19     0.31             03/17/20
# 20     0.29             03/16/20
# 21     0.37                  NaN
# 22     0.31             03/16/20
# 23     0.30             03/18/20
# 24     0.31             03/19/20
# 25     0.29             03/20/20
# 26     0.34             03/16/20
# 27     0.29             03/16/20
# 28     0.28             03/16/20
# 29     0.29                  NaN
# 30     0.34             03/16/20
# 31     0.30             03/18/20
# 32     0.31             03/16/20
# 33     0.29             03/16/20
# 34     0.30             03/18/20
# 35     0.31             03/17/20
# 36     0.29             03/17/20
# 37     0.31             03/16/20
# 38     0.32             03/16/20
# 39     0.32             03/16/20
# 40     0.32             03/16/20
# 41     0.30             03/16/20
# 42     0.29             03/20/20
# 43     0.24             03/23/20
# 44     0.21             03/16/20
# 45     0.29             03/16/20
# 46     0.36             03/18/20
# 47     0.29             03/17/20
# 48     0.31             03/18/20
# 49     0.35             03/16/20
# 50     0.31             03/20/20
#
# [51 rows x 26 columns]

# %%
# This function does median split based a given values in `sr`
# and split `df` into two groups
def medianSplitGroups(sr, df, col):
    median = sr.median()
    print(f"median value: {median}")
    group1 = []
    group2 = []

    for i in range(len(sr)):
        if sr[i] < median:
            group1.append(sr.index[i])
        else:
            group2.append(sr.index[i])
            
    group1Df = df[df[col].isin(group1)]
    group2Df = df[df[col].isin(group2)]
            
    # collapse the columns in each group into one column
    return (group1Df, group2Df)

# %%
# filter date and format date col 
ny_cols = ['NY', 'NYC']

def filterByYear(df, date_col, year):
    df[date_col] = pd.to_datetime(df[date_col], infer_datetime_format=True)
    return df[df[date_col].dt.strftime('%Y') == year]

covid_cases_cols = ['submission_date', 'state', 'new_case', 'tot_cases']
covid_cases = covid_cases[covid_cases_cols]
covid_cases = filterByYear(covid_cases, 'submission_date', '2020')

# merge NY and NYC data
cases_indexed = covid_cases.groupby(['submission_date','state']).sum()

indexes = cases_indexed.index
date_index = np.unique(np.array([ind[0] for ind in indexes]))

for date_ind in date_index: 
    cases_indexed.loc[date_ind, 'NY'] = sum(cases_indexed.loc[date_ind, 'NY'], cases_indexed.loc[date_ind, 'NYC'])

cases_indexed.reset_index(inplace=True, level=['submission_date', 'state'])

new_cases = cases_indexed
new_cases[(new_cases['submission_date'] == '2020-12-31')].sort_values('state').head(10)
# Out:
#       submission_date state  new_case  tot_cases
# 20640      2020-12-31    AK     372.0    45771.0
# 20641      2020-12-31    AL    4784.0   362094.0
# 20642      2020-12-31    AR    2708.0   225138.0
# 20643      2020-12-31    AS       0.0        3.0
# 20644      2020-12-31    AZ    7721.0   520559.0
# 20645      2020-12-31    CA   13410.0  2231552.0
# 20646      2020-12-31    CO    2858.0   347198.0
# 20647      2020-12-31    CT    2045.0   185708.0
# 20648      2020-12-31    DC     225.0    28983.0
# 20649      2020-12-31    DE     626.0    58847.0

# %%
# state trips data 
state_trips_col = ['Date', 
                   'State Postal Code', 
                   'Number of Trips', 
                   'Number of Trips 5-10', 
                   'Number of Trips 25-50', 
                   'Number of Trips 100-250', 
                   'Number of Trips 250-500']
state_trips = state_trips[state_trips_col]
state_trips = filterByYear(state_trips, 'Date', '2020')

# %%
# rename so the merge is valid
new_cases.rename(columns={'submission_date' : 'date'}, inplace=True)
state_trips.rename(columns={'Date' : 'date', 'State Postal Code' : 'state'}, inplace=True)

# merge all dfs
new_case_trips = new_cases.merge(state_trips, on=['date', 'state'], how='inner')
final_data = new_case_trips.merge(pop_by_state, on='state', how='inner')
final_data.replace(',','', regex=True, inplace=True)


# normalize number of trips 
num_trips_cols = ['Number of Trips', 'Number of Trips 5-10', 'Number of Trips 25-50', 'Number of Trips 100-250', 'Number of Trips 250-500']
for col in num_trips_cols:
    final_data[col] = final_data[col].astype(float) / final_data['Population']

# normalize num of new cases
final_data['new_case_ratio'] = final_data['new_case']  / final_data['Population']
final_data['tot_case_ratio'] = final_data['tot_cases']  / final_data['Population']

# %%
# Find median of num trips in each state 
numTripsByState = final_data.groupby('state').sum()['Number of Trips']
# stateCases2020[stateCases2020['state'].isin(blueCode)]
(lessTravelled, moreTravelled) = medianSplitGroups(numTripsByState, final_data, 'state')
# Out:
# median value: 1055.940446343205

# %%
lessTravelledByState = lessTravelled.groupby('state').sum()['new_case_ratio'].reset_index()
moreTravelledByState = moreTravelled.groupby('state').sum()['new_case_ratio'].reset_index()

# %%
fig = plt.figure(1)
ax = fig.add_axes([0,0,1,1])
ax.bar(lessTravelledByState['state'], lessTravelledByState['new_case_ratio'], color='c')
plt.title('Less travelled state')
plt.xlabel('Less travelled state')
plt.ylabel('Case per population')
plt.show()

# %%
fig = plt.figure(1)
ax = fig.add_axes([0,0,1,1])
ax.bar(moreTravelledByState['state'], moreTravelledByState['new_case_ratio'], color='m')
plt.title('More travelled state')
plt.xlabel('More travelled state')
plt.ylabel('Case per population')
plt.show()

# %%
#Run an independent t-test on the two populations/groups to check whether or not there is a difference in their means 
stats.ttest_ind(moreTravelledByState['new_case_ratio'], lessTravelledByState['new_case_ratio'])
# Out:
# Ttest_indResult(statistic=1.0264346098521449, pvalue=0.309831784614011)

# %%
stats.ttest_ind(moreTravelled['new_case_ratio'], lessTravelled['new_case_ratio'], alternative='greater')
# Out:
# Ttest_indResult(statistic=15.511558124929799, pvalue=3.3502906368304237e-54)

# %%
lessTravelled.columns
# Out:
# Index(['state', 'new_case_ratio'], dtype='object')

# %%
lessTravelled.mean()
# Out:
# new_case_ratio    0.00018
# dtype: float64

# %%
moreTravelled.mean()
# Out:
# new_case_ratio    0.000548
# dtype: float64

# %%
moreTravelledByState.mean()
# Out:
# new_case_ratio    0.188975
# dtype: float64

# %%
lessTravelledByState.mean()
# Out:
# new_case_ratio    0.062163
# dtype: float64
